# %%
import ROOT as r 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# Out:
# Welcome to JupyROOT 6.24/02

# %%
directory= "/Users/adit/Google Drive/Internship_ Research/Muon g-2/Data Filed/combined_forAdit_timealigned.root"
f = r.TFile(directory)

# %%
f.cd('LaserEvents')
t = f.Get('LaserEvents/tree')
df = pd.DataFrame(r.RDataFrame(t).AsNumpy())
c= r.TCanvas()

# %%
run = 25026
subRun = 2
fill = 178
calo = 20
xtal =14

# %%
print(df.describe())
print(df.nunique())
print(df.head())
# Out:
#        gpsTimeStamp  cccTimeStamp        runNum     subRunNum       fillNum  \
# count  3.779552e+07  3.779552e+07  3.779552e+07  3.779552e+07  3.779552e+07
# mean   1.555790e+09  9.911910e+10  2.496101e+04  2.245266e+02  1.342963e+02
# std    2.544310e+05  5.867342e+10  8.201021e+01  1.350690e+02  7.734417e+01
# min    1.554982e+09  2.163583e+08  2.468500e+04  0.000000e+00  1.000000e+00
# 25%    1.555664e+09  4.969637e+10  2.492800e+04  1.090000e+02  6.600000e+01
# 50%    1.556000e+09  9.647675e+10  2.502600e+04  2.150000e+02  1.370000e+02
# 75%    1.556003e+09  1.477690e+11  2.502600e+04  3.380000e+02  1.960000e+02
# max    1.556034e+09  2.220666e+11  2.503200e+04  4.930000e+02  3.770000e+02
#
#            bunchNum    fillType       caloNum       xtalNum      sipmTime  \
# count  3.779552e+07  37795516.0  3.779552e+07  3.779552e+07  3.779552e+07
# mean   7.500986e+00         1.0  1.249642e+01  2.651775e+01  1.989889e+05
# std    4.609085e+00         0.0  6.923995e+00  1.557810e+01  2.085139e+05
# min    0.000000e+00         1.0  1.000000e+00  0.000000e+00 -1.013165e+05
# 25%    3.000000e+00         1.0  6.000000e+00  1.300000e+01  2.593025e+04
# 50%    8.000000e+00         1.0  1.200000e+01  2.700000e+01  2.019006e+05
# 75%    1.200000e+01         1.0  1.900000e+01  4.000000e+01  3.778777e+05
# max    1.500000e+01         1.0  2.400000e+01  5.300000e+01  5.539283e+05
#
#        ...     lmPmtAmp1     lmPmtAmp2    lmPmtArea1    lmPmtArea2  \
# count  ...  3.779552e+07  3.779552e+07  3.779552e+07  3.779552e+07
# mean   ...  1.030401e+03  5.830605e+02  2.303769e+04  1.242125e+04
# std    ...  2.458946e+02  5.879159e+01  5.552233e+03  1.254522e+03
# min    ...  4.592000e+02  3.689400e+02  1.002900e+04  7.992000e+03
# 25%    ...  8.898800e+02  5.612600e+02  1.983600e+04  1.176700e+04
# 50%    ...  9.569000e+02  5.933000e+02  2.170800e+04  1.272700e+04
# 75%    ...  1.171980e+03  6.214400e+02  2.606100e+04  1.328500e+04
# max    ...  1.798300e+03  7.626400e+02  4.052500e+04  1.605900e+04
#
#          lmPmtTime1    lmPmtTime2       slmTime     slmEnergy   slmPedestal  \
# count  3.779552e+07  3.779552e+07  3.779552e+07  3.779552e+07  3.779552e+07
# mean   3.037033e+05  3.038922e+05  1.989861e+05  3.014385e+03 -1.792727e+03
# std    2.085140e+05  2.085140e+05  2.085150e+05  6.492897e+02  1.138986e+01
# min    5.278000e+03  5.467000e+03 -1.013160e+05  1.034929e+02 -1.810825e+03
# 25%    1.306320e+05  1.308210e+05  2.592841e+04  2.322185e+03 -1.802486e+03
# 50%    3.066260e+05  3.068150e+05  2.018997e+05  3.082035e+03 -1.795191e+03
# 75%    4.826110e+05  4.828000e+05  3.778766e+05  3.588007e+03 -1.782144e+03
# max    6.586310e+05  6.588200e+05  5.539251e+05  7.004196e+03 -1.750374e+03
#
#             slmChi2
# count  3.779552e+07
# mean   1.725921e+01
# std    6.921721e+01
# min    5.359833e+00
# 25%    1.150315e+01
# 50%    1.525729e+01
# 75%    1.911204e+01
# max    7.142990e+03
#
# [8 rows x 29 columns]
# gpsTimeStamp        6353
# cccTimeStamp        6353
# runNum                18
# subRunNum            340
# fillNum              334
# bunchNum              16
# fillType               1
# caloNum               24
# xtalNum               54
# sipmTime        36822917
# sipmEnergy      37795515
# sipmPedestal    37795510
# sipmChi2        37795515
# smPin1Amp           9125
# smPin1Time          2095
# smPin2Amp          10044
# smPin2Time          2014
# smPmtAmp               1
# smPmtTime              1
# lmPmtAmp1          52803
# lmPmtAmp2          16427
# lmPmtArea1         24840
# lmPmtArea2          7065
# lmPmtTime1         10103
# lmPmtTime2         10524
# slmTime           142930
# slmEnergy         175150
# slmPedestal       175150
# slmChi2           175150
# dtype: int64
#    gpsTimeStamp  cccTimeStamp  runNum  subRunNum  fillNum  bunchNum  fillType  \
# 0  1.555667e+09  1.880835e+11   24928        412      178         0         1
# 1  1.555667e+09  1.880835e+11   24928        412      178         0         1
# 2  1.555667e+09  1.880835e+11   24928        412      178         0         1
# 3  1.555667e+09  1.880835e+11   24928        412      178         0         1
# 4  1.555667e+09  1.880835e+11   24928        412      178         0         1
#
#    caloNum  xtalNum     sipmTime  ...  lmPmtAmp1  lmPmtAmp2  lmPmtArea1  \
# 0        1        0 -99404.10462  ...    1244.28     638.28     27700.0
# 1        1        1 -99404.14162  ...    1244.28     638.28     27700.0
# 2        1        2 -99404.23262  ...    1244.28     638.28     27700.0
# 3        1        3 -99403.93562  ...    1244.28     638.28     27700.0
# 4        1        4 -99404.06962  ...    1244.28     638.28     27700.0
#
#    lmPmtArea2  lmPmtTime1  lmPmtTime2      slmTime    slmEnergy  slmPedestal  \
# 0     13555.0      5290.0      5478.0 -99406.16062  3837.187198 -1803.181425
# 1     13555.0      5290.0      5478.0 -99406.16062  3837.187198 -1803.181425
# 2     13555.0      5290.0      5478.0 -99406.16062  3837.187198 -1803.181425
# 3     13555.0      5290.0      5478.0 -99406.16062  3837.187198 -1803.181425
# 4     13555.0      5290.0      5478.0 -99406.16062  3837.187198 -1803.181425
#
#      slmChi2
# 0  21.196002
# 1  21.196002
# 2  21.196002
# 3  21.196002
# 4  21.196002
#
# [5 rows x 29 columns]

# %%
t.Draw('slmTime:fillNum', "caloNum =={} && xtalNum =={}".format(calo,xtal), 'colz')
c.Draw()
c.SetLogy(0)

# %%
t.Draw('sipmTime:fillNum', "caloNum =={} && xtalNum =={}".format(calo,xtal), 'colz')
c.Draw()
c.SetLogy(0)

# %%
t.Draw('sipmTime-slmTime', "caloNum ==1 && xtalNum ==1")
c.SetLogy()
c.Draw()

# %%
df_filtered = df.loc[(df['sipmTime']-df['slmTime']) < 50]
df_noise = df.loc[(df['sipmTime']-df['slmTime']) > 50]
#evaluated this in a diff notebook, nothing significant, no commonalities, only 47 of 29k entries

# %%
#syncPulse = df_xtal.groupby(['runNum','subRunNum','fillNum']).idxmin()['slmTime'].reset_index()
#print(syncPulse['slmTime'])
#df_xtal.iloc[syncPulse['slmTime']]
# Out:
# 0       20297336
# 1       20302516
# 2       20308721
# 3       20315196
# 4       20321671
#           ...
# 6348    29203900
# 6349    29209076
# 6350    29214252
# 6351    29220453
# 6352    29226923
# Name: slmTime, Length: 6353, dtype: int64

# %%
df_xtal = df_filtered[(df_filtered['caloNum']==calo)& (df_filtered['xtalNum']==xtal)]
syncPulse = df_xtal[df_xtal['slmTime']< -10000][['runNum','subRunNum','fillNum', 'slmEnergy']]
laserPulse = df_xtal[df_xtal['slmTime']> -10000]

# %%
syncPulse.rename({'slmEnergy': 'syncEnergy'}, axis = 'columns',inplace=True )
laserPulse  = pd.merge(laserPulse,syncPulse, how = 'inner', on = ['runNum','subRunNum','fillNum'])
laserPulse['normalSlmEnergy'] = (laserPulse['slmEnergy']/laserPulse['syncEnergy'])

# %%
h0 = r.TH1D(f"h_{0}", "SLM Energy of Calo {} xtal {}; SLM Energy; Frequency".format(calo,xtal), 200, 1000, 5000)

for x in laserPulse['slmEnergy']:
    h0.Fill(x)

h0.Draw()
c.Draw()
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h_0 (Potential memory leak).

# %%
c.SetLogy()

h1 = r.TH1D(f"h_{1}", "Normal SLM Energy of Calo {} xtal {}; Normalized SLM Energy; Frequency".format(calo,xtal), 200, 0.6, 1.4)

for x in laserPulse['normalSlmEnergy']:
    h1.Fill(x)

h1.Draw()
c.Draw()

#see a spike at 1, probably because of a large proportion of sync Pulses
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h_1 (Potential memory leak).

# %%
h2 = r.TH1D(f"h_{2}", "Calo Energy of Calo {} xtal {}; SiPM Energy (raw); Frequency".format(calo,xtal), 250, 500, 2000)

for x in laserPulse['sipmEnergy']:
    h2.Fill(x)

h2.Draw()
c.Draw()
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h_2 (Potential memory leak).

# %%
h3 = r.TH1D(f"h_{3}", "Distribution of Energy Ratio of Calo {} xtal {}; SiPM/ Normalized SLM Energy; Frequency".format(calo,xtal), 200, 600, 1800)

for x in laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']:
    h3.Fill(x)

h3.Draw()
c.Draw()

mean_temp = h3.GetMean()
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h_3 (Potential memory leak).

# %%
h4 = r.TH2D(f"h_{4}", "Distribution of Energy Ratio of Calo {} xtal {}; Calo Time(in 1000 clock ticks); Calo Energy Normalized to SLM Energy".format(calo,xtal),
            200, -50, 600,
            200,0.5,1.5)

for (x,y) in zip(laserPulse['sipmTime'], laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean_temp):
    h4.Fill(x/1000,y)

h4.Draw('colz')
c.Draw()
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h_4 (Potential memory leak).

# %%
fig,ax = plt.subplots()
ax.plot(laserPulse['sipmTime'],laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean_temp,".")
ax.set_title("Time stability of Laser Pulse for Calo{} xtal{}".format(calo,xtal))
ax.set_xlabel("slmTime")
ax.set_ylabel("Normalised Laser SLM Energy")
# fit a curve (linear for now) through the stability of time 

def func(x,m,b):
    return m*x + b 

initial_guess = [1.2, 0.03]
pars, pcov = curve_fit(func, laserPulse['sipmTime'], laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean_temp, p0=initial_guess)
xfit = np.linspace(np.amin(laserPulse['sipmTime']),np.amax(laserPulse['sipmTime']))
yfit = func(xfit, pars[0], pars[1])
plt.plot(xfit,yfit,'r-',label=f"Linear Fit\nm={pars[0]:.2f}\nb={pars[1]:.2f}")

print("Slope: {}".format(pars[0]))
print("Standard Deviation: {}".format(np.sqrt(pcov[1,1])))
# Out:
# Slope: -2.089342053159197e-09
# Standard Deviation: 0.00082959424295297

# %%
gr = r.TGraph() 
gr.SetTitle(" Graph for Time Stability; SLM Time; Energy Ratio")

for i in range(laserPulse.shape[0]):
    gr.SetPoint(i, laserPulse['sipmTime'][i],laserPulse['sipmEnergy'][i]/laserPulse['normalSlmEnergy'][i]/mean_temp) #each point has an index as well as the data value

c = r.TCanvas()
gr.Draw()
c.Draw()

# %%
func2 = r.TF1("func2","[0](-x)* + [1]",0,600000) 
func2.SetParameters(0.01,1)
func2.SetNpx(1000)

#c = r.TCanvas()
#gr.Fit(func2)
#h.Draw()
#c.Draw()

# %%
#automation of the whole process to find out errors and time stabilities of all calo

timeGrowth = np.zeros((24,54))
timeStd = np.zeros((24,54))

for calo in pd.unique(df['caloNum'])[:14]:
    for xtal in  pd.unique(df['xtalNum']):

        df_xtal = df_filtered[(df_filtered['caloNum']==calo)& (df_filtered['xtalNum']==xtal)]
        syncPulse = df_xtal[df_xtal['slmTime']< -10000][['runNum','subRunNum','fillNum', 'slmEnergy']]
        laserPulse = df_xtal[df_xtal['slmTime']> -10000]
        
        syncPulse.rename({'slmEnergy': 'syncEnergy'}, axis = 'columns',inplace=True )
        laserPulse  = pd.merge(laserPulse,syncPulse, how = 'inner', on = ['runNum','subRunNum','fillNum'])
        laserPulse['normalSlmEnergy'] = (laserPulse['slmEnergy']/laserPulse['syncEnergy'])
        
        mean = laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy'].mean()
        
        def func(x,m,b):
            return m*x + b 

        initial_guess = [1.2, 0.03]
        pars, pcov = curve_fit(func, laserPulse['sipmTime'], laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean, p0=initial_guess)

        timeGrowth[calo-1][xtal] = pars[0]
        timeStd[calo-1][xtal] = np.sqrt(pcov[1,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bg/h849yg0s2771n7mypkp93k680000gn/T/ipykernel_40996/3123037535.py in <module>
#      21
#      22         initial_guess = [1.2, 0.03]
# ---> 23         pars, pcov = curve_fit(func, laserPulse['sipmTime'], laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean, p0=initial_guess)
#      24
#      25         timeGrowth[calo-1][xtal] = pars[0]
#
# ~/opt/anaconda3/envs/ROOT/lib/python3.9/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     746
#     747     if ydata.size == 0:
# --> 748         raise ValueError("`ydata` must not be empty!")
#     749
#     750     # Determine type of sigma
#
# ValueError: `ydata` must not be empty!

# %%
#I just split this automation into two parts because it was giving some memort error for running all of it at once

for calo in pd.unique(df['caloNum'])[14:]:
    for xtal in  pd.unique(df['xtalNum']):

        df_xtal = df_filtered[(df_filtered['caloNum']==calo)& (df_filtered['xtalNum']==xtal)]
        syncPulse = df_xtal[df_xtal['slmTime']< -10000][['runNum','subRunNum','fillNum', 'slmEnergy']]
        laserPulse = df_xtal[df_xtal['slmTime']> -10000]
        
        syncPulse.rename({'slmEnergy': 'syncEnergy'}, axis = 'columns',inplace=True )
        laserPulse  = pd.merge(laserPulse,syncPulse, how = 'inner', on = ['runNum','subRunNum','fillNum'])
        laserPulse['normalSlmEnergy'] = (laserPulse['slmEnergy']/laserPulse['syncEnergy'])
        
        mean = laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy'].mean()
        
        def func(x,m,b):
            return m*x + b 

        initial_guess = [1.2, 0.03]
        pars, pcov = curve_fit(func, laserPulse['sipmTime'], laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean, p0=initial_guess)

        timeGrowth[calo-1][xtal] = pars[0]
        timeStd[calo-1][xtal] = np.sqrt(pcov[1,1])

# %%
for xtal in  pd.unique(df['xtalNum']):

    df_xtal = df_filtered[(df_filtered['caloNum']==calo)& (df_filtered['xtalNum']==xtal)]
    syncPulse = df_xtal[df_xtal['slmTime']< -10000][['runNum','subRunNum','fillNum', 'slmEnergy']]
    laserPulse = df_xtal[df_xtal['slmTime']> -10000]

    syncPulse.rename({'slmEnergy': 'syncEnergy'}, axis = 'columns',inplace=True )
    laserPulse  = pd.merge(laserPulse,syncPulse, how = 'inner', on = ['runNum','subRunNum','fillNum'])
    laserPulse['normalSlmEnergy'] = (laserPulse['slmEnergy']/laserPulse['syncEnergy'])

    mean = laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy'].mean()

    def func(x,m,b):
        return m*x + b 

    initial_guess = [1.2, 0.03]
    pars, pcov = curve_fit(func, laserPulse['sipmTime'], laserPulse['sipmEnergy']/laserPulse['normalSlmEnergy']/mean, p0=initial_guess)

    timeGrowth[calo-1][xtal] = pars[0]
    timeStd[calo-1][xtal] = np.sqrt(pcov[1,1])

# %%
##use profile_x for fitting

# %%
#timeGrowth is change of Energy Ratio per ns (or clock tick, ambiguous) --> maybe ct only cause sipmTime doesn't go all the way to 600k
fillTime = 600000 # in ns (may change to ct )
infill_RatioChange = timeGrowth*fillTime

# %%
plt.rcParams["figure.figsize"] = (12,6) 
scale1 = (10**4)

print("Change of Energy Ratio during a fill scaled by {}".format(scale1))

for calo in pd.unique(df['caloNum']):
    fig,ax = plt.subplots()
    im = ax.imshow(infill_RatioChange[calo-1].reshape(6,9)*scale1,cmap=plt.cm.Blues)
    for i in range(6):
        for j in range(9):
            text = ax.text(j, i,"{0:.2f}".format(infill_RatioChange[calo-1].reshape(6,9)[i, j]*scale1),
                           ha="center", va="center", color="black")        
    plt.title('Calo {}'.format(calo))
    plt.show()
# Out:
# Change of Energy Ratio during a fill scaled by 10000

# %%
plt.rcParams["figure.figsize"] = (12,6) 

scale2 = (10**4)

print("Error in Energy Ratio scaled by {}".format(scale2))

for calo in pd.unique(df['caloNum']):
    fig,ax = plt.subplots()
    im = ax.imshow(timeStd[calo-1].reshape(6,9)*scale2,cmap=plt.cm.Oranges)
    for i in range(6):
        for j in range(9):
            text = ax.text(j, i,"{0:.2f}".format(timeStd[calo-1].reshape(6,9)[i, j]*scale2),
                           ha="center", va="center", color="black")        
    plt.title('Calo {}'.format(calo))
    plt.show()
# Out:
# Error in Rate of Change of Energy Ratio scaled by 10000

# %%
caloAvgChange = np.zeros(24)
for calo in pd.unique(df['caloNum']):
    caloAvgGrowth[calo-1] = infill_RatioChange[calo-1].mean()
    
caloAvgError = np.zeros(24)
for calo in pd.unique(df['caloNum']):
    caloAvgError[calo-1] = timeStd[calo-1].max()

# %%
calo = 11
h5 = r.TH1D(f"h_{5}", "Error in Time Stability of Calo {}; Error; Frequency".format(calo), 50, timeStd[calo-1].min(), timeStd[calo-1].max())

for x in timeStd[calo-1]:
    h5.Fill(x)

h5.Draw()
c.Draw()

#semi
# Out:
# Warning in <TDirectoryFile::Append>: Replacing existing TH1: h_5 (Potential memory leak).

# %%
fig, ax = plt.subplots()

ax.errorbar(pd.unique(df['caloNum']), caloAvgGrowth, yerr= caloAvgError, lw = 2,capsize = 4, capthick = 4, ecolor = "blue", color = 'black')
plt.xlabel("Calo Number")
plt.ylabel("Average Change in Calo")
plt.title("inFill Energy Ratio Changes for all Calo")
plt.show()

# %%
infill_RatioChange[1][0]
# Out:
# -0.00023718786864490989
